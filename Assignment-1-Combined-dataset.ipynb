# %%
import pandas as pd;
df = pd.read_csv("data/Combined_dataset.csv");
df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %% [markdown]
# Head() - shows top 5 rows

# %%
df.head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    rating  ratings_count  initial_price  discount  final_price currency  \
# 0     3.8             15           3995      58.0  "₹3,995.00"      INR
# 1     4.5             67           2899      35.0  "₹2,899.00"      INR
# 2     4.4            226           2999      65.0  "₹2,999.00"      INR
# 3     4.4           1052           1675      52.0  "₹1,675.00"      INR
# 4     4.7             12           2899      17.0  "₹2,899.00"      INR
#
#                                               images  ...  \
# ...

# %% [markdown]
# Tail() - shows bottom 5 rows

# %%
df.tail()
# Out:
#      product_id     title                                product_description  \
# 995    13698258     KREDO  Men FORTE Silver Automatic Skeleton Analogue W...
# 996    16896006     GUESS  Women White Patterned Dial & White Straps Anal...
# 997     1708108  GIORDANO  Women Rose Gold-Toned Mirrored Analogue Watch ...
# 998    19280114  Fastrack  Men Black Brass Dial & Black Stainless Steel S...
# 999    18601682   BOLDFIT                           Purple Textured Yoga Mat
#
#      rating  ratings_count  initial_price  discount   final_price currency  \
# 995     3.5             11          11890      50.0  "₹11,890.00"      INR
# 996     5.0             22           8900      45.0   "₹8,900.00"      INR
# 997     2.8              5           7950      50.0   "₹7,950.00"      INR
# 998     4.3             17           3295      20.0   "₹2,636.00"      INR
# 999     3.8            161            699      31.0     "₹699.00"      INR
#
# ...

# %% [markdown]
# Check shape - (rows & column)

# %%
df.shape
# Out:
# (1000, 24)

# %% [markdown]
# View Column Names

# %%
df.columns
# Out:
# Index(['product_id', 'title', 'product_description', 'rating', 'ratings_count',
#        'initial_price', 'discount', 'final_price', 'currency', 'images',
#        'delivery_options', 'product_details', 'breadcrumbs',
#        'product_specifications', 'amount_of_stars', 'what_customers_said',
#        'seller_name', 'sizes', 'videos', 'seller_information', 'variations',
#        'best_offer', 'more_offers', 'category'],
#       dtype='str')

# %% [markdown]
# Check datatypes

# %%
df.dtypes
# Out:
# product_id                  int64
# title                         str
# product_description           str
# rating                    float64
# ratings_count               int64
# initial_price               int64
# discount                  float64
# final_price                   str
# currency                      str
# images                        str
# delivery_options              str
# product_details               str
# breadcrumbs                   str
# product_specifications        str
# amount_of_stars               str
# what_customers_said           str
# seller_name                   str
# sizes                         str
# videos                        str
# seller_information            str
# variations                    str
# best_offer                    str
# more_offers                   str
# category                      str
# dtype: object

# %% [markdown]
# Handling Missing Values

# %%
df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   str
#  2   product_description     1000 non-null   str
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                879 non-null    float64
#  7   final_price             1000 non-null   str
#  8   currency                1000 non-null   str
#  9   images                  1000 non-null   str
#  10  delivery_options        1000 non-null   str
#  11  product_details         1000 non-null   str
#  12  breadcrumbs             1000 non-null   str
#  13  product_specifications  1000 non-null   str
#  14  amount_of_stars         1000 non-null   str
# ...

# %%
df[["discount"]]
# Out:
#      discount
# 0        58.0
# 1        35.0
# 2        65.0
# 3        52.0
# 4        17.0
# ..        ...
# 995      50.0
# 996      45.0
# 997      50.0
# 998      20.0
# 999      31.0
#
# [1000 rows x 1 columns]

# %%
df["discount"] = df["discount"].fillna(df["discount"].mean())
df["discount"]
# Out:
# 0      58.0
# 1      35.0
# 2      65.0
# 3      52.0
# 4      17.0
#        ...
# 995    50.0
# 996    45.0
# 997    50.0
# 998    20.0
# 999    31.0
# Name: discount, Length: 1000, dtype: float64

# %%
df["what_customers_said"]
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      NaN
#       ...
# 995    NaN
# 996    NaN
# 997    NaN
# 998    NaN
# 999    NaN
# Name: what_customers_said, Length: 1000, dtype: str

# %%
df["what_customers_said"] = df["what_customers_said"].fillna("No Review");
df["what_customers_said"]
# Out:
# 0      No Review
# 1      No Review
# 2      No Review
# 3      No Review
# 4      No Review
#          ...
# 995    No Review
# 996    No Review
# 997    No Review
# 998    No Review
# 999    No Review
# Name: what_customers_said, Length: 1000, dtype: str

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   str
#  2   product_description     1000 non-null   str
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                1000 non-null   float64
#  7   final_price             1000 non-null   str
#  8   currency                1000 non-null   str
#  9   images                  1000 non-null   str
#  10  delivery_options        1000 non-null   str
#  11  product_details         1000 non-null   str
#  12  breadcrumbs             1000 non-null   str
#  13  product_specifications  1000 non-null   str
#  14  amount_of_stars         1000 non-null   str
# ...

# %%
df["seller_name"]
# Out:
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                 NaN
#             ...
# 995               NaN
# 996               NaN
# 997               NaN
# 998    Tru███m R███il
# 999               NaN
# Name: seller_name, Length: 1000, dtype: str

# %%
df["seller_name"] = df["seller_name"].fillna("Unknown Seller")
df["seller_name"]
# Out:
# 0      Unknown Seller
# 1      Unknown Seller
# 2      Unknown Seller
# 3      Unknown Seller
# 4      Unknown Seller
#             ...
# 995    Unknown Seller
# 996    Unknown Seller
# 997    Unknown Seller
# 998    Tru███m R███il
# 999    Unknown Seller
# Name: seller_name, Length: 1000, dtype: str

# %%
df["videos"]
# Out:
# 0                                  ["rw-8376765_cae700"]
# 1                                  ["rw-9136281_cae700"]
# 2      ["https://videos.myntassets.com/assets/videos/...
# 3      ["https://videos.myntassets.com/assets/videos/...
# 4                                                    NaN
#                              ...
# 995                                      ["pi-13698258"]
# 996    ["rw-16896006_cae700","https://videos.myntasse...
# 997                                                  NaN
# 998                                                  NaN
# 999                                                  NaN
# Name: videos, Length: 1000, dtype: str

# %%
df["videos"] = df["videos"].fillna("Unknown")

# %%
df["videos"]
# Out:
# 0                                  ["rw-8376765_cae700"]
# 1                                  ["rw-9136281_cae700"]
# 2      ["https://videos.myntassets.com/assets/videos/...
# 3      ["https://videos.myntassets.com/assets/videos/...
# 4                                                Unknown
#                              ...
# 995                                      ["pi-13698258"]
# 996    ["rw-16896006_cae700","https://videos.myntasse...
# 997                                              Unknown
# 998                                              Unknown
# 999                                              Unknown
# Name: videos, Length: 1000, dtype: str

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   str
#  2   product_description     1000 non-null   str
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                1000 non-null   float64
#  7   final_price             1000 non-null   str
#  8   currency                1000 non-null   str
#  9   images                  1000 non-null   str
#  10  delivery_options        1000 non-null   str
#  11  product_details         1000 non-null   str
#  12  breadcrumbs             1000 non-null   str
#  13  product_specifications  1000 non-null   str
#  14  amount_of_stars         1000 non-null   str
# ...

# %%
df["variations"]
# Out:
# 0                                             [{}]
# 1                                          [{},{}]
# 2                              [{},{},{},{},{},{}]
# 3                                              NaN
# 4      [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]
#                           ...
# 995                                            NaN
# 996                                            NaN
# 997                      [{},{},{},{},{},{},{},{}]
# 998                                            NaN
# 999                                  [{},{},{},{}]
# Name: variations, Length: 1000, dtype: str

# %%
df["variations"] = df["variations"].fillna("[{}]")

# %%
df["variations"]
# Out:
# 0                                             [{}]
# 1                                          [{},{}]
# 2                              [{},{},{},{},{},{}]
# 3                                             [{}]
# 4      [{},{},{},{},{},{},{},{},{},{},{},{},{},{}]
#                           ...
# 995                                           [{}]
# 996                                           [{}]
# 997                      [{},{},{},{},{},{},{},{}]
# 998                                           [{}]
# 999                                  [{},{},{},{}]
# Name: variations, Length: 1000, dtype: str

# %%
df["seller_information"]
# Out:
# 0                                                    NaN
# 1                                                    NaN
# 2                                                    NaN
# 3                                                    NaN
# 4                                                    NaN
#                              ...
# 995                                                  NaN
# 996                                                  NaN
# 997                                                  NaN
# 998    Sho███o. ███-10█████████enu███████████████████...
# 999                                                  NaN
# Name: seller_information, Length: 1000, dtype: str

# %%
df["seller_information"] = df["seller_information"].fillna("no information known")

# %%
df["seller_information"]
# Out:
# 0                                   no information known
# 1                                   no information known
# 2                                   no information known
# 3                                   no information known
# 4                                   no information known
#                              ...
# 995                                 no information known
# 996                                 no information known
# 997                                 no information known
# 998    Sho███o. ███-10█████████enu███████████████████...
# 999                                 no information known
# Name: seller_information, Length: 1000, dtype: str

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   str
#  2   product_description     1000 non-null   str
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                1000 non-null   float64
#  7   final_price             1000 non-null   str
#  8   currency                1000 non-null   str
#  9   images                  1000 non-null   str
#  10  delivery_options        1000 non-null   str
#  11  product_details         1000 non-null   str
#  12  breadcrumbs             1000 non-null   str
#  13  product_specifications  1000 non-null   str
#  14  amount_of_stars         1000 non-null   str
# ...

# %%
df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %% [markdown]
# Basic Operations

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   product_id              1000 non-null   int64
#  1   title                   1000 non-null   str
#  2   product_description     1000 non-null   str
#  3   rating                  1000 non-null   float64
#  4   ratings_count           1000 non-null   int64
#  5   initial_price           1000 non-null   int64
#  6   discount                1000 non-null   float64
#  7   final_price             1000 non-null   str
#  8   currency                1000 non-null   str
#  9   images                  1000 non-null   str
#  10  delivery_options        1000 non-null   str
#  11  product_details         1000 non-null   str
#  12  breadcrumbs             1000 non-null   str
#  13  product_specifications  1000 non-null   str
#  14  amount_of_stars         1000 non-null   str
# ...

# %% [markdown]
# Select Columns

# %%
df[["product_id","title", "product_description", "final_price", "amount_of_stars"]].head()
# Out:
#    product_id           title                         product_description  \
# 0     8376765     Lino Perros              Women Navy Blue Solid Backpack
# 1     9136281  Tommy Hilfiger           Unisex Navy Blue Striped Backpack
# 2    17633752           Lavie              Aries Women Pink Mini Backpack
# 3     1376949          F Gear  Unisex Navy & Grey Printed Burner Backpack
# 4    13939916       MYTRIDENT                    Men Blue Solid Bath Robe
#
#    final_price                                    amount_of_stars
# 0  "₹3,995.00"  {"1_star":2,"2_stars":0,"3_stars":3,"4_stars":...
# 1  "₹2,899.00"  {"1_star":3,"2_stars":4,"3_stars":2,"4_stars":...
# 2  "₹2,999.00"  {"1_star":9,"2_stars":5,"3_stars":10,"4_stars"...
# 3  "₹1,675.00"  {"1_star":33,"2_stars":21,"3_stars":69,"4_star...
# 4  "₹2,899.00"  {"1_star":0,"2_stars":0,"3_stars":0,"4_stars":...

# %%
df[["product_id", "title", "product_details", "seller_name", "category"]].head(50)
# Out:
#     product_id                    title  \
# 0      8376765              Lino Perros
# 1      9136281           Tommy Hilfiger
# 2     17633752                    Lavie
# 3      1376949                   F Gear
# 4     13939916                MYTRIDENT
# 5     17198778                      H&M
# 6     19851824               AVI Living
# 7     18602872                  My Room
# 8     18602850                  My Room
# 9      8961147               Story@home
# 10     8430275                MYTRIDENT
# 11    18346118                   Arrabi
# 12    18327434               BELLA CASA
# 13    18492504                    ROMEE
# 14    13729978                   DDecor
# 15    19788630             Home Ecstasy
# 16    20296382            DREAM WEAVERZ
# 17    18346134                   Arrabi
# 18    22409156                  Kastner
# 19    18985918           Tommy Hilfiger
# 20    22120138          Ed-a-Mamma Baby
# 21     1728397                  Mactree
# ...

# %% [markdown]
# 2.Filter

# %%
df[df["rating"] > 4.0]
# Out:
#      product_id              title  \
# 1       9136281     Tommy Hilfiger
# 2      17633752              Lavie
# 3       1376949             F Gear
# 4      13939916          MYTRIDENT
# 5      17198778                H&M
# ..          ...                ...
# 991     2466414       Daniel Klein
# 992    11791782              CASIO
# 994     8481603  French Connection
# 996    16896006              GUESS
# 998    19280114           Fastrack
#
#                                    product_description  rating  ratings_count  \
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# 5           Beige & Tan Solid Stoneware Soap Dispenser     4.5             42
# ...

# %%
df[(df["rating"] > 2.5) & (df["rating"] <= 4.0)]
# Out:
#      product_id        title  \
# 0       8376765  Lino Perros
# 6      19851824   AVI Living
# 9       8961147   Story@home
# 13     18492504        ROMEE
# 14     13729978       DDecor
# ..          ...          ...
# 990     9053317    TIMESMITH
# 993    19322504          V2A
# 995    13698258        KREDO
# 997     1708108     GIORDANO
# 999    18601682      BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 6            Grey Solid 500 GSM Pure Cotton Bath Towel     4.0              5
# 9    Pink & White Floral 160 TC Cotton 1 King Bedsh...     3.7              7
# 13   Blue & Beige Conversational 160 TC King Bedshe...     3.9             10
# 14   White & Brown Floral 350 TC Cotton 1 King Beds...     3.6             15
# ..                                                 ...     ...            ...
# ...

# %%
df[["final_price"]]
# Out:
#       final_price
# 0     "₹3,995.00"
# 1     "₹2,899.00"
# 2     "₹2,999.00"
# 3     "₹1,675.00"
# 4     "₹2,899.00"
# ..            ...
# 995  "₹11,890.00"
# 996   "₹8,900.00"
# 997   "₹7,950.00"
# 998   "₹2,636.00"
# 999     "₹699.00"
#
# [1000 rows x 1 columns]

# %%
df["final_price"] = df["final_price"].str.replace("₹", "")
df["final_price"] = df["final_price"].str.replace(",", "")
df["final_price"]
# Out:
# 0       "3995.00"
# 1       "2899.00"
# 2       "2999.00"
# 3       "1675.00"
# 4       "2899.00"
#           ...
# 995    "11890.00"
# 996     "8900.00"
# 997     "7950.00"
# 998     "2636.00"
# 999      "699.00"
# Name: final_price, Length: 1000, dtype: str

# %%
df["final_price"] = df["final_price"].str.replace('"', "")
df["final_price"]
# Out:
# 0       3995.00
# 1       2899.00
# 2       2999.00
# 3       1675.00
# 4       2899.00
#          ...
# 995    11890.00
# 996     8900.00
# 997     7950.00
# 998     2636.00
# 999      699.00
# Name: final_price, Length: 1000, dtype: str

# %%
df["final_price"] = df['final_price'].astype(float)

# %%
df["final_price"]
# Out:
# 0       3995.0
# 1       2899.0
# 2       2999.0
# 3       1675.0
# 4       2899.0
#         ...
# 995    11890.0
# 996     8900.0
# 997     7950.0
# 998     2636.0
# 999      699.0
# Name: final_price, Length: 1000, dtype: float64

# %%
df[df["final_price"] > 1500.0]
# Out:
#      product_id              title  \
# 0       8376765        Lino Perros
# 1       9136281     Tommy Hilfiger
# 2      17633752              Lavie
# 3       1376949             F Gear
# 4      13939916          MYTRIDENT
# ..          ...                ...
# 994     8481603  French Connection
# 995    13698258              KREDO
# 996    16896006              GUESS
# 997     1708108           GIORDANO
# 998    19280114           Fastrack
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ...

# %% [markdown]
# Remove Duplicates

# %%
df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df.duplicated()
# Out:
# 0      False
# 1      False
# 2      False
# 3      False
# 4      False
#        ...
# 995    False
# 996    False
# 997    False
# 998    False
# 999    False
# Length: 1000, dtype: bool

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %% [markdown]
# No duplicates found

# %% [markdown]
# Creating a derived column

# %%
df["quantity"] = 2;
df["total_amount"] = df["final_price"] * df["quantity"]
df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df
# Out:
#      product_id           title  \
# 0       8376765     Lino Perros
# 1       9136281  Tommy Hilfiger
# 2      17633752           Lavie
# 3       1376949          F Gear
# 4      13939916       MYTRIDENT
# ..          ...             ...
# 995    13698258           KREDO
# 996    16896006           GUESS
# 997     1708108        GIORDANO
# 998    19280114        Fastrack
# 999    18601682         BOLDFIT
#
#                                    product_description  rating  ratings_count  \
# 0                       Women Navy Blue Solid Backpack     3.8             15
# 1                    Unisex Navy Blue Striped Backpack     4.5             67
# 2                       Aries Women Pink Mini Backpack     4.4            226
# 3           Unisex Navy & Grey Printed Burner Backpack     4.4           1052
# 4                             Men Blue Solid Bath Robe     4.7             12
# ..                                                 ...     ...            ...
# ...

# %%
df.to_csv("Combined_cleaned_dataset.csv", index=False)
